# %%
import pandas as pd
import requests

# %%
request = requests.get(
            "https://services1.arcgis.com/WzFsmainVTuD5KML/"
            "arcgis/rest/services/Daily_Cases_Hospitalizations_and_Deaths/"
            "FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json"
        ).json()

# %%
request
# Out:
# {'objectIdFieldName': 'ObjectId',
#  'uniqueIdField': {'name': 'ObjectId', 'isSystemMaintained': True},
#  'globalIdFieldName': '',
#  'fields': [{'name': 'ObjectId',
#    'type': 'esriFieldTypeOID',
#    'alias': 'ObjectId',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'All_Cases',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'All Cases',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'All_Cases__Cumulative_',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'All Cases (Cumulative)',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Community_Cases',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'Community Cases',
#    'sqlType': 'sqlTypeOther',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Community_Cases__Cumulative_',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'Community Cases (Cumulative)',
# ...

# %%
len("CY1LXxl9zlJeBuRZ")
# Out:
# 16

# %%
len("WzFsmainVTuD5KML")
# Out:
# 16
